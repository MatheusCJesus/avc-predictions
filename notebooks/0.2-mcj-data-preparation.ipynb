# %% [markdown]
# ## Overview
#
# ### Data preparation for analysis
#
# * Read CSV files
# * Select the important columns
# * Transform to parquet

# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %% [markdown]
# EDA

# %%
df = pd.read_csv("../data/raw/datasus_13_18/RDMT1301.csv", encoding='unicode_escape')

# %%
df = df.dropna(axis=1)
df
# Out:
#         UF_ZI  ANO_CMPT  MES_CMPT  ESPEC          N_AIH  IDENT       CEP  \
# 0      510000      2013         1      1  5113100165745      1  78110970
# 1      510000      2013         1      1  5113100165900      1  78110970
# 2      510000      2013         1      1  5113100165910      1  78110970
# 3      510000      2013         1      1  5113100165921      1  78110970
# 4      510000      2013         1      1  5113100165932      1  78110970
# ...       ...       ...       ...    ...            ...    ...       ...
# 14848  510860      2013         1      3  5113100377528      1  78645000
# 14849  510860      2013         1      3  5113100377539      1  78645000
# 14850  510860      2013         1      3  5113100377540      1  78645000
# 14851  510860      2013         1      3  5113100377550      1  78645000
# 14852  510860      2013         1      3  5113100377572      1  78645000
#
#        MUNIC_RES      NASC  SEXO  ...  RACA_COR  ETNIA  SEQUENCIA  \
# 0         510840  19890620     1  ...         1      0        782
# 1         510840  19701004     1  ...         3      0        783
# 2         510840  19950109     1  ...        99      0        784
# 3         510840  19781216     1  ...         3      0        785
# 4         510840  20050531     3  ...         3      0        786
# ...          ...       ...   ...  ...       ...    ...        ...
# 14848     510860  19800304     1  ...         3      0         88
# 14849     510860  19350926     3  ...         3      0         89
# 14850     510860  19840711     3  ...         3      0         90
# 14851     510860  19310722     1  ...         3      0         91
# 14852     510860  19450925     3  ...         3      0         92
#
#                      REMESSA  VAL_SH_FED  VAL_SP_FED  VAL_SH_GES  VAL_SP_GES  \
# 0      HE51000001N201301.DTS         0.0         0.0         0.0         0.0
# 1      HE51000001N201301.DTS         0.0         0.0         0.0         0.0
# 2      HE51000001N201301.DTS         0.0         0.0         0.0         0.0
# 3      HE51000001N201301.DTS         0.0         0.0         0.0         0.0
# 4      HE51000001N201301.DTS         0.0         0.0         0.0         0.0
# ...                      ...         ...         ...         ...         ...
# 14848  HM51086001N201301.DTS         0.0         0.0         0.0         0.0
# 14849  HM51086001N201301.DTS         0.0         0.0         0.0         0.0
# 14850  HM51086001N201301.DTS         0.0         0.0         0.0         0.0
# 14851  HM51086001N201301.DTS         0.0         0.0         0.0         0.0
# 14852  HM51086001N201301.DTS         0.0         0.0         0.0         0.0
#
#        VAL_UCI  MARCA_UCI
# 0          0.0          0
# 1          0.0          0
# 2          0.0          0
# 3          0.0          0
# 4          0.0          0
# ...        ...        ...
# 14848      0.0          0
# 14849      0.0          0
# 14850      0.0          0
# 14851      0.0          0
# 14852      0.0          0
#
# [14853 rows x 82 columns]

# %%
df = df[df.UF_ZI == 510340]

# %%
df_important_columns = df[["DIAG_PRINC", "DT_INTER"]]

# %%
df_important_columns.reset_index(drop="index")
# Out:
#      DIAG_PRINC  DT_INTER
# 0           I10  20121226
# 1          B207  20121229
# 2          R571  20121229
# 3          A412  20121129
# 4          J159  20121214
# ...         ...       ...
# 3355       O141  20121226
# 3356        G35  20121207
# 3357        G35  20121217
# 3358        G35  20121121
# 3359        I10  20130109
#
# [3360 rows x 2 columns]

# %%
df_important_columns["data"] = pd.to_datetime(df_important_columns.DT_INTER, format='%Y%m%d')
# Out:
# /tmp/ipykernel_7735/2322479761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_important_columns["data"] = pd.to_datetime(df_important_columns.DT_INTER, format='%Y%m%d')

# %%
df_important_columns = df_important_columns.drop(columns="DT_INTER")

# %%
df_important_columns = df_important_columns.sort_values(by=['data'], ascending=True)

# %%
# df_filtered = df_important_columns[(df_important_columns.DIAG_PRINC == "I64") | (df_important_columns.DIAG_PRINC.str.contains("J"))]
df_filtered = df_important_columns[df_important_columns.DIAG_PRINC.str.contains("J")]

# %%
df_filtered.DIAG_PRINC.unique()
# Out:
# array(['J189', 'J152', 'J159', 'J449', 'J985', 'J188', 'J81', 'J960',
#        'J930', 'J969', 'J068', 'J459', 'J110', 'J180', 'J353', 'J168',
#        'J350', 'J100', 'J80', 'J182', 'J938', 'J448', 'J955', 'J390',
#        'J342', 'J668', 'J90', 'J219', 'J852', 'J351', 'J958', 'J040',
#        'J392', 'J36', 'J158', 'J942', 'J128', 'J352', 'J320', 'J339'],
#       dtype=object)

# %%
df_filtered
# Out:
#       DIAG_PRINC       data
# 9495        J189 2012-08-09
# 9569        J152 2012-08-10
# 9494        J159 2012-08-26
# 9200        J449 2012-08-28
# 9835        J985 2012-09-03
# ...          ...        ...
# 10290       J128 2013-01-11
# 10293       J158 2013-01-12
# 10292       J128 2013-01-12
# 10652       J320 2013-01-13
# 7665        J339 2013-01-14
#
# [227 rows x 2 columns]

# %% [markdown]
# Defining functions

# %%
def concat_csv_files(path: str):
   # importing packages
    import pandas as pd
    import glob

    folder_path = path
    file_list = glob.glob(folder_path + "/*.csv")
    main_dataframe = pd.read_csv(file_list[0], encoding='unicode_escape')
    
    for i in range(1,len(file_list)):
        data = pd.read_csv(file_list[i], encoding='unicode_escape')
        main_dataframe = pd.concat([main_dataframe,data], ignore_index=True)

    return main_dataframe

# %%
# def filter_df(ds: pd.DataFrame):

#     df = ds[ds.UF_ZI == 510340]
#     df = df[["DIAG_PRINC", "IDADE", "DT_INTER"]].reset_index(drop="index")
#     df["data"] = pd.to_datetime(df.DT_INTER, format='%Y%m%d')
#     df = df.drop(columns="DT_INTER")
#     df = df.sort_values(by=['data'], ascending=True)
#     df = df[(df.DIAG_PRINC == "I64") | (df.DIAG_PRINC.str.contains("J"))]

#     df.insert(2, "respiratory", 0)
#     df.insert(3, "avc", 0)

#     df.respiratory.loc[df.DIAG_PRINC.str.contains("J")] = 1
#     df.avc.loc[df.DIAG_PRINC.str.contains("I")] = 1

#     return df

def filter_df(ds: pd.DataFrame):

    df = ds[ds.UF_ZI == 510340]
    df = df[["DIAG_PRINC", "DT_INTER"]].reset_index(drop="index")
    df["data"] = pd.to_datetime(df.DT_INTER, format='%Y%m%d')
    df = df.drop(columns="DT_INTER")
    df = df.sort_values(by=['data'], ascending=True)
    df = df[df.DIAG_PRINC.str.contains("J")]

    df.insert(2, "respiratory", 0)

    df.respiratory.loc[df.DIAG_PRINC.str.contains("J")] = 1

    return df

# %%
df = filter_df(concat_csv_files('../data/raw/datasus_13_18'))
# Out:
# /tmp/ipykernel_7735/1265479210.py:8: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_dataframe = pd.read_csv(file_list[0], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (87,88,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')
# /tmp/ipykernel_7735/1265479210.py:11: DtypeWarning: Columns (61,87,88,96,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_list[i], encoding='unicode_escape')

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns="index", inplace=True)
df
# Out:
#       DIAG_PRINC       data  respiratory
# 0           J189 2012-08-09            1
# 1           J152 2012-08-10            1
# 2           J159 2012-08-26            1
# 3           J449 2012-08-28            1
# 4           J985 2012-09-03            1
# ...          ...        ...          ...
# 17347       J180 2018-12-13            1
# 17348       J449 2018-12-13            1
# 17349       J159 2018-12-18            1
# 17350       J189 2018-12-18            1
# 17351       J189 2018-12-23            1
#
# [17352 rows x 3 columns]

# %%
df
# Out:
#       DIAG_PRINC       data  respiratory
# 0           J189 2012-08-09            1
# 1           J152 2012-08-10            1
# 2           J159 2012-08-26            1
# 3           J449 2012-08-28            1
# 4           J985 2012-09-03            1
# ...          ...        ...          ...
# 17347       J180 2018-12-13            1
# 17348       J449 2018-12-13            1
# 17349       J159 2018-12-18            1
# 17350       J189 2018-12-18            1
# 17351       J189 2018-12-23            1
#
# [17352 rows x 3 columns]

# %%
df_datetime = pd.DataFrame(pd.date_range(start="2013/1/1", end="2018/12/31", freq='D'), columns=["date"])
df_datetime.insert(1, "respiratory", 0)
df_datetime
# Out:
#            date  respiratory
# 0    2013-01-01            0
# 1    2013-01-02            0
# 2    2013-01-03            0
# 3    2013-01-04            0
# 4    2013-01-05            0
# ...         ...          ...
# 2186 2018-12-27            0
# 2187 2018-12-28            0
# 2188 2018-12-29            0
# 2189 2018-12-30            0
# 2190 2018-12-31            0
#
# [2191 rows x 2 columns]

# %%
df = df.loc[~(df.data.dt.year == 2012)]

# %%
df_sum = df.groupby("data").sum(numeric_only=True)

# %%
df_datetime = pd.merge(df_datetime, df_sum, how="left", right_on="data", left_on="date")

# %%
df_datetime = df_datetime.fillna(0)

# %%
df_datetime.drop(columns=["respiratory_x"], inplace=True)
df_datetime.rename(columns={"respiratory_y": "respiratory"}, inplace=True)

# %%
df_datetime
# Out:
#            date  respiratory
# 0    2013-01-01          6.0
# 1    2013-01-02          8.0
# 2    2013-01-03         12.0
# 3    2013-01-04          9.0
# 4    2013-01-05         10.0
# ...         ...          ...
# 2186 2018-12-27          0.0
# 2187 2018-12-28          0.0
# 2188 2018-12-29          0.0
# 2189 2018-12-30          0.0
# 2190 2018-12-31          0.0
#
# [2191 rows x 2 columns]

# %% [markdown]
# Preparing air quality data

# %%
df_air = concat_csv_files("../data/raw/air_quality/")
df_air
# Out:
#               datahora  co_ppb  no2_ppb  o3_ppb  pm25_ugm3  so2_ugm3  \
# 0     2016-01-01 00:00   183.4      1.1     9.4       16.9       0.9
# 1     2016-01-01 06:00   191.6      1.8     7.0       15.8       1.4
# 2     2016-01-01 12:00   192.8      1.0     7.0       20.8       0.6
# 3     2016-01-01 18:00   184.9      0.1    12.7       16.0       0.3
# 4     2016-01-02 00:00   201.0      1.4     7.0       16.8       1.1
# ...                ...     ...      ...     ...        ...       ...
# 8759  2015-12-30 18:00   246.9      0.1    27.2       21.8       0.2
# 8760  2015-12-31 00:00   289.5      1.9    14.4       25.2       1.4
# 8761  2015-12-31 06:00   297.1      1.0    20.7       28.3       0.9
# 8762  2015-12-31 12:00   226.0      0.6    14.6       20.9       0.6
# 8763  2015-12-31 18:00   171.7      0.0    16.2       17.3       0.2
#
#       precipitacao_mmdia  temperatura_c  umidade_relativa_percentual  \
# 0                    0.0           27.6                           85
# 1                    NaN           24.8                           94
# 2                    NaN           27.8                           86
# 3                    NaN           29.3                           77
# 4                    3.0           25.7                           92
# ...                  ...            ...                          ...
# 8759                 NaN           29.5                           70
# 8760                 0.0           26.2                           88
# 8761                 NaN           24.8                           88
# 8762                 NaN           28.0                           77
# 8763                 NaN           28.9                           78
#
#       vento_direcao_grau  vento_velocidade_ms  focos_queimada  mun_geocod  \
# 0                   38.0                  1.3             NaN     5103403
# 1                    7.0                  1.9             NaN     5103403
# 2                    1.0                  1.7             NaN     5103403
# 3                  301.0                  2.1             NaN     5103403
# 4                   56.0                  1.2             NaN     5103403
# ...                  ...                  ...             ...         ...
# 8759                 NaN                  NaN             NaN     5103403
# 8760                 NaN                  NaN             NaN     5103403
# 8761                 NaN                  NaN             NaN     5103403
# 8762                 NaN                  NaN             NaN     5103403
# 8763                 NaN                  NaN             NaN     5103403
#
#      mun_nome  mun_lat  mun_lon  mun_uf_nome
# 0     CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 1     CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 2     CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 3     CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 4     CUIABÃ -15.5987 -56.0991  MATO GROSSO
# ...       ...      ...      ...          ...
# 8759  CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 8760  CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 8761  CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 8762  CUIABÃ -15.5987 -56.0991  MATO GROSSO
# 8763  CUIABÃ -15.5987 -56.0991  MATO GROSSO
#
# [8764 rows x 17 columns]

# %%
columns_to_drop = ["vento_direcao_grau", "vento_velocidade_ms",
"mun_geocod", "mun_lat", "mun_lon", "no2_ppb", "mun_nome", "mun_uf_nome"]

# %%
df_air.drop(columns=columns_to_drop, inplace=True)
df_air
# Out:
#               datahora  co_ppb  o3_ppb  pm25_ugm3  so2_ugm3  \
# 0     2016-01-01 00:00   183.4     9.4       16.9       0.9
# 1     2016-01-01 06:00   191.6     7.0       15.8       1.4
# 2     2016-01-01 12:00   192.8     7.0       20.8       0.6
# 3     2016-01-01 18:00   184.9    12.7       16.0       0.3
# 4     2016-01-02 00:00   201.0     7.0       16.8       1.1
# ...                ...     ...     ...        ...       ...
# 8759  2015-12-30 18:00   246.9    27.2       21.8       0.2
# 8760  2015-12-31 00:00   289.5    14.4       25.2       1.4
# 8761  2015-12-31 06:00   297.1    20.7       28.3       0.9
# 8762  2015-12-31 12:00   226.0    14.6       20.9       0.6
# 8763  2015-12-31 18:00   171.7    16.2       17.3       0.2
#
#       precipitacao_mmdia  temperatura_c  umidade_relativa_percentual  \
# 0                    0.0           27.6                           85
# 1                    NaN           24.8                           94
# 2                    NaN           27.8                           86
# 3                    NaN           29.3                           77
# 4                    3.0           25.7                           92
# ...                  ...            ...                          ...
# 8759                 NaN           29.5                           70
# 8760                 0.0           26.2                           88
# 8761                 NaN           24.8                           88
# 8762                 NaN           28.0                           77
# 8763                 NaN           28.9                           78
#
#       focos_queimada
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 8759             NaN
# 8760             NaN
# 8761             NaN
# 8762             NaN
# 8763             NaN
#
# [8764 rows x 9 columns]

# %%
df_air.datahora = df_air.datahora.astype("datetime64[ns]")
df_air.datahora = df_air.datahora.dt.date

# %%
df_air.fillna(0, inplace=True)

# %%
df_air = df_air.groupby("datahora").mean().reset_index()
df_air
# Out:
#         datahora   co_ppb  o3_ppb  pm25_ugm3  so2_ugm3  precipitacao_mmdia  \
# 0     2013-01-01  135.400  11.125      8.175     0.875                0.50
# 1     2013-01-02  155.050  10.925     11.675     1.000                0.50
# 2     2013-01-03  137.400  12.225      8.800     0.825                0.00
# 3     2013-01-04  128.300  13.750     11.650     0.925                0.25
# 4     2013-01-05  128.250  10.950      7.800     1.075                2.25
# ...          ...      ...     ...        ...       ...                 ...
# 2186  2018-12-27   78.375   3.750      7.850     0.750                0.00
# 2187  2018-12-28   66.450   4.625      6.100     0.350                7.00
# 2188  2018-12-29   66.275   4.675      6.050     0.300                0.50
# 2189  2018-12-30   59.925   5.700      4.750     0.300                1.00
# 2190  2018-12-31   63.225   3.375      6.775     0.475                0.25
#
#       temperatura_c  umidade_relativa_percentual  focos_queimada
# 0            26.450                        81.75             0.0
# 1            26.400                        82.00             0.0
# 2            27.400                        81.25             0.0
# 3            27.750                        76.25             0.0
# 4            26.625                        84.75             0.0
# ...             ...                          ...             ...
# 2186         26.000                        96.50             0.0
# 2187         26.000                        96.25             0.0
# 2188         25.700                        96.25             0.0
# 2189         25.575                        95.50             0.0
# 2190         25.050                        96.50             0.0
#
# [2191 rows x 9 columns]

# %%
df_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   datahora                     2191 non-null   object
#  1   co_ppb                       2191 non-null   float64
#  2   o3_ppb                       2191 non-null   float64
#  3   pm25_ugm3                    2191 non-null   float64
#  4   so2_ugm3                     2191 non-null   float64
#  5   precipitacao_mmdia           2191 non-null   float64
#  6   temperatura_c                2191 non-null   float64
#  7   umidade_relativa_percentual  2191 non-null   float64
#  8   focos_queimada               2191 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 154.2+ KB

# %%
df_air.datahora = df_air.datahora.astype("datetime64[ns]")

# %%
df_air.dtypes
# Out:
# datahora                       datetime64[ns]
# co_ppb                                float64
# o3_ppb                                float64
# pm25_ugm3                             float64
# so2_ugm3                              float64
# precipitacao_mmdia                    float64
# temperatura_c                         float64
# umidade_relativa_percentual           float64
# focos_queimada                        float64
# dtype: object

# %%
df_complete = pd.merge(df_air, df_datetime, how="left", right_on="date", left_on="datahora")

# %%
columns_to_drop = ["date"]
df_complete.drop(columns_to_drop, inplace=True, axis=1)
df_complete.rename(columns={"datahora": "date"}, inplace=True)

# %%
columns_order = ["date", "co_ppb", "o3_ppb", "pm25_ugm3",
"so2_ugm3", "temperatura_c", "umidade_relativa_percentual",
"precipitacao_mmdia", "focos_queimada", "respiratory"]
df_complete = df_complete[columns_order]

# %%
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2191 entries, 0 to 2190
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         2191 non-null   datetime64[ns]
#  1   co_ppb                       2191 non-null   float64
#  2   o3_ppb                       2191 non-null   float64
#  3   pm25_ugm3                    2191 non-null   float64
#  4   so2_ugm3                     2191 non-null   float64
#  5   temperatura_c                2191 non-null   float64
#  6   umidade_relativa_percentual  2191 non-null   float64
#  7   precipitacao_mmdia           2191 non-null   float64
#  8   focos_queimada               2191 non-null   float64
#  9   respiratory                  2191 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 188.3 KB

# %%
# df_complete.to_parquet("../data/processed/new-avc.parquert")

# %%
df_complete
# Out:
#            date   co_ppb  o3_ppb  pm25_ugm3  so2_ugm3  temperatura_c  \
# 0    2013-01-01  135.400  11.125      8.175     0.875         26.450
# 1    2013-01-02  155.050  10.925     11.675     1.000         26.400
# 2    2013-01-03  137.400  12.225      8.800     0.825         27.400
# 3    2013-01-04  128.300  13.750     11.650     0.925         27.750
# 4    2013-01-05  128.250  10.950      7.800     1.075         26.625
# ...         ...      ...     ...        ...       ...            ...
# 2186 2018-12-27   78.375   3.750      7.850     0.750         26.000
# 2187 2018-12-28   66.450   4.625      6.100     0.350         26.000
# 2188 2018-12-29   66.275   4.675      6.050     0.300         25.700
# 2189 2018-12-30   59.925   5.700      4.750     0.300         25.575
# 2190 2018-12-31   63.225   3.375      6.775     0.475         25.050
#
#       umidade_relativa_percentual  precipitacao_mmdia  focos_queimada  \
# 0                           81.75                0.50             0.0
# 1                           82.00                0.50             0.0
# 2                           81.25                0.00             0.0
# 3                           76.25                0.25             0.0
# 4                           84.75                2.25             0.0
# ...                           ...                 ...             ...
# 2186                        96.50                0.00             0.0
# 2187                        96.25                7.00             0.0
# 2188                        96.25                0.50             0.0
# 2189                        95.50                1.00             0.0
# 2190                        96.50                0.25             0.0
#
#       respiratory
# 0             6.0
# 1             8.0
# 2            12.0
# 3             9.0
# 4            10.0
# ...           ...
# 2186          0.0
# 2187          0.0
# 2188          0.0
# 2189          0.0
# 2190          0.0
#
# [2191 rows x 10 columns]
